# %%
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
def plots(freqs, measures, order, ylabels=None):
    fig = plt.figure(figsize=(20, 75))
    colors = np.random.uniform(0,0.6, (len(list(measures.keys())), 3))
    
    for num, measure in enumerate(measures.keys()):
        ax = fig.add_subplot(int(round(freqs.shape[0]*9/3)), 3, num + 1)
        ax.plot(freqs[order], np.array(measures[measure], dtype='float')[order],
                    color = colors[num], marker = 'o', linestyle=':')
        ax.set_title((measure.upper()).replace('_', ' '), fontsize=25)
        ax.plot(0, 0, marker=' ', linestyle=' ')
        ax.grid()
        plt.xlabel('Hz', fontsize=15)
        if not(ylabels == None):
            plt.ylabel(ylabels[num], fontsize=15, rotation=0, labelpad=25)

    plt.tight_layout()
    plt.show()
    
def read_measures_freqs(dataset_base_path):
    csvs_names = os.listdir(dataset_base_path)

    jpdaf_dir = [name for name in csvs_names]

    measures = {
        'vcl': [],
        'vsl': [],
        'vap_mean': [],
        'alh_mean': [],
        'lin': [],
        'wob': [],
        'str': [],
        'bcf_mean': [],
        'mad': [],
        'fluo': []
    }
    
    ylabels = [r'$\frac{\mu m}{s}$', r'$\frac{\mu m}{s}$', r'$\frac{\mu m}{s}$', 
              r'$\mu m$', '', '', '', 'Hz', r'$\mu m$', 'mgv']
    
    freqs = []
    for freq in jpdaf_dir:
        print(freq)
        fps = (freq.split('Hz'))[0].split('(')[-1]
        freqs.append(fps)
        full_path_file = os.path.join(dataset_base_path, freq)
        freq_df = pd.read_csv(full_path_file)
        for measure in list(measures.keys()):
            measures[measure].append(freq_df[measure].mean())

    freqs = np.array(freqs, dtype='int')
    order = np.argsort(freqs)
    return freqs, measures, order, ylabels

def plot3D(dataset_base_path, name='out.png'):
    from mpl_toolkits.mplot3d import Axes3D
    csvs_names = os.listdir(dataset_base_path)

    jpdaf_dir = [name for name in csvs_names]
    measures = {
        'alh_mean': [],
        'wob': [],
        'str': [],
    }
    
    ylabels = ['alh', 'wob', 'str']
    
    freqs = []
    for freq in jpdaf_dir:
        fps = (freq.split('Hz'))[0].split('(')[-1]
        if fps == '30':
            fig = plt.figure()
            ax = Axes3D(fig)
            freqs.append(fps)
            full_path_file = os.path.join(dataset_base_path, freq)
            freq_df = pd.read_csv(full_path_file)
            
            ax.scatter(freq_df['str'], freq_df['wob'], freq_df['alh_mean'], marker='o')
            ax.set_xlabel('STR')
            ax.set_ylabel('WOB')
            ax.set_zlabel('ALH')
            plt.savefig(name)
    return

# %%
indir = 'measures'
dataset = 'dataset_1'

dataset_base_path = os.path.join(indir, dataset)
freqs, measures, order, ylabels = read_measures_freqs(dataset_base_path)
#plots(freqs, measures, order, ylabels)
plot3D(dataset_base_path)
# Out:
# dataset_1(40Hz)_data_WHO.csv
# dataset_1(30Hz)_data_WHO.csv
# dataset_1(6Hz)_data_WHO.csv
# dataset_1(15Hz)_data_WHO.csv
# dataset_1(60Hz)_data_WHO.csv
# dataset_1(20Hz)_data_WHO.csv

# %%
# %matplotlib inline
indir = 'measures'
dataset = 'dataset_1'

dataset_base_path = os.path.join(indir, dataset)
freqs, measures, order, ylabels = read_measures_freqs(dataset_base_path)
plots(freqs, measures, order, ylabels)
# Out:
# dataset_1(40Hz)_data_WHO.csv
# dataset_1(30Hz)_data_WHO.csv
# dataset_1(6Hz)_data_WHO.csv
# dataset_1(15Hz)_data_WHO.csv
# dataset_1(60Hz)_data_WHO.csv
# dataset_1(20Hz)_data_WHO.csv

# %%
indir = 'measures'
dataset = 'dataset_3'

dataset_base_path = os.path.join(indir, dataset)
freqs, measures, order, ylabels = read_measures_freqs(dataset_base_path)
plots(freqs, measures, order, ylabels)
# Out:
# dataset_3(60Hz)_data_WHO.csv
# dataset_3(15Hz)_data_WHO.csv
# dataset_3(20Hz)_data_WHO.csv
# dataset_3(30Hz)_data_WHO.csv
# dataset_3(40Hz)_data_WHO.csv
# dataset_3(6Hz)_data_WHO.csv

# %%
indir = 'measures'
dataset = 'dataset_4'

dataset_base_path = os.path.join(indir, dataset)
freqs, measures, order, ylabels = read_measures_freqs(dataset_base_path)
plots(freqs, measures, order, ylabels)
# Out:
# dataset_4(40Hz)_data_WHO.csv
# dataset_4(15Hz)_data_WHO.csv
# dataset_4(60Hz)_data_WHO.csv
# dataset_4(6Hz)_data_WHO.csv
# dataset_4(20Hz)_data_WHO.csv
# dataset_4(30Hz)_data_WHO.csv

# %%
indir = 'measures'
dataset = 'dataset_5'

dataset_base_path = os.path.join(indir, dataset)
freqs, measures, order, ylabels = read_measures_freqs(dataset_base_path)
plots(freqs, measures, order, ylabels)
# Out:
# dataset_5(30Hz)_data_WHO.csv
# dataset_5(20Hz)_data_WHO.csv
# dataset_5(15Hz)_data_WHO.csv
# dataset_5(60Hz)_data_WHO.csv
# dataset_5(6Hz)_data_WHO.csv
# dataset_5(40Hz)_data_WHO.csv

# %%
indir = 'measures'
dataset = 'dataset_6'

dataset_base_path = os.path.join(indir, dataset)
freqs, measures, order, ylabels= read_measures_freqs(dataset_base_path)
plots(freqs, measures, order, ylabels)
# Out:
# dataset_6(30Hz)_data_WHO.csv
# dataset_6(60Hz)_data_WHO.csv
# dataset_6(15Hz)_data_WHO.csv
# dataset_6(20Hz)_data_WHO.csv
# dataset_6(40Hz)_data_WHO.csv
# dataset_6(6Hz)_data_WHO.csv

# %%
full_path_file = 'measures/dataset_5/dataset_5_30Hz_ennjpdaf_WHO.csv'

freq_df = pd.read_csv(full_path_file)
vap_freq =[[v, f] for v,f in zip(freq_df['vap_mean'], freq_df['fluo']) if v>0 and f>0 and v<400]
v, f = [v[0] for v in vap_freq], [f[1] for f in vap_freq]
plt.plot(v, f, marker='*', linestyle=' ')
plt.plot(0, 0, marker='None')
plt.xlabel('vap')
plt.grid()
plt.ylabel('fluo')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'fluo')

# %%
freq_df
# Out:
#     track_id         vcl         vsl    vap_mean       vap_std  alh_mean  \
# 0          1  351.915139   80.912597  239.160067    726.579752  1.098227
# 1          2  190.170079   90.424840  117.883603     91.387856  0.920058
# 2          3  680.992126   30.874391  321.956055   7517.295859  2.655935
# 3          4  181.840387  104.195544  138.577793     80.603363  0.726301
# 4          5  466.743431   24.926764  324.943644  12070.108774  1.262273
# ..       ...         ...         ...         ...           ...       ...
# 62        88  428.823411   42.178051  156.994240   1458.383689  1.503307
# 63        89    0.000000    0.000000    0.000000      0.000000  0.000000
# 64        90    0.000000    0.000000    0.000000      0.000000  0.000000
# 65        91  222.716342   91.979930  125.049500     65.281239  1.158887
# 66        93  492.721543   39.725392  336.866929    760.757419  1.416427
#
#      alh_std       lin       wob       str   bcf_mean    bcf_std       mad  \
# 0   1.029782  0.229921  0.679596  0.338320  20.000000   0.000000  1.771702
# 1   0.678912  0.475495  0.619885  0.767069  56.000000  12.000000  1.266958
# 2   2.475304  0.045337  0.472775  0.095896  41.766667  20.398012  1.960515
# 3   0.430125  0.573006  0.762085  0.751892  51.071429  13.716332  2.497057
# 4   1.185088  0.053406  0.696193  0.076711  38.742347  20.664704  1.639742
# ..       ...       ...       ...       ...        ...        ...       ...
# 62  1.728471  0.098358  0.366105  0.268660  30.000000  15.491933  2.308195
# 63  0.000000  0.000000  0.000000  0.000000   0.000000   0.000000  0.000000
# 64  0.000000  0.000000  0.000000  0.000000   0.000000   0.000000  0.000000
# 65  0.856615  0.412991  0.561474  0.735548  60.000000   0.000000  1.447018
# 66  1.547889  0.080624  0.683686  0.117926  60.000000   0.000000  1.321389
#
#           fluo
# 0          NaN
# 1    96.533875
# 2   100.168675
# 3          NaN
# 4    86.761628
# ..         ...
# 62         NaN
# 63    0.000000
# 64    0.000000
# 65  104.099602
# 66   77.385000
#
# [67 rows x 14 columns]

# %%
full_path_file = 'measures/dataset_4/dataset_4_60Hz_ennjpdaf_WHO.csv'
freq_df = pd.read_csv(full_path_file)
print(len(freq_df['fluo']), len(freq_df['fluo']) - freq_df['fluo'].count())
print(len(freq_df[freq_df['vap_mean']==0]))
v, f = freq_df['vap_mean'].to_numpy(), freq_df['fluo'].to_numpy()
plt.plot(v, f, marker='*', linestyle=' ')
plt.xlabel('vap')
plt.ylabel('fluo')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-97d3fa824476> in <module>
#       1 full_path_file = 'measures/dataset_4/dataset_4_60Hz_ennjpdaf_WHO.csv'
# ----> 2 freq_df = pd.read_csv(full_path_file)
#       3 print(len(freq_df['fluo']), len(freq_df['fluo']) - freq_df['fluo'].count())
#       4 print(len(freq_df[freq_df['vap_mean']==0]))
#       5 v, f = freq_df['vap_mean'].to_numpy(), freq_df['fluo'].to_numpy()
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # REAL DATA

# %%
# !ls real_sequences/
# Out:
# 1 026          11             9              tracks_WHO.csv
# 10             4              tiff_files

# %%
indir = 'real_sequences/1 026/tracks_WHO.csv'
csv = pd.read_csv(indir)

# %%
plt.plot(csv['vap_mean'], csv['fluo'], marker='.', linestyle=' ')
plt.xlabel('vap_mean')
plt.ylabel('fluo')
# Out:
# Text(0, 0.5, 'fluo')

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)

ax.scatter(csv['str'], csv['wob'], csv['alh_mean'], marker='o')
ax.set_xlabel('STR')
ax.set_ylabel('WOB')
ax.set_zlabel('ALH')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from sklearn.cluster import KMeans 

str_list, wob_list, alh_list = º].to_list(), csv['wob'].to_list(), csv['alh_mean'].to_list()
values = [(stra, wob, alh) for stra, wob, alh in zip(str_list, wob_list, alh_list)]

kmeans = KMeans(n_clusters=3).fit(values)
labels = kmeans.predict(values)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)

colors = [(1,0,0), (0,1,0), (0,0,1)]

for it, label in enumerate(labels):
    
    ax.plot(values[it][0], values[it][1], values[it][2], marker='o', color=colors[label])
ax.set_xlabel('STR')
ax.set_ylabel('WOB')
ax.set_zlabel('ALH')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# !jupyter nbconvert degradation_plots.ipynb --to=pdf --TemplateExporter.exclude_input=True
# Out:
# [NbConvertApp] Converting notebook degradation_plots.ipynb to pdf
# [NbConvertApp] Support files will be in degradation_plots_files/
# [NbConvertApp] Making directory ./degradation_plots_files
# [NbConvertApp] Making directory ./degradation_plots_files
# [NbConvertApp] Making directory ./degradation_plots_files
# [NbConvertApp] Making directory ./degradation_plots_files
# [NbConvertApp] Making directory ./degradation_plots_files
# [NbConvertApp] Making directory ./degradation_plots_files
# [NbConvertApp] Making directory ./degradation_plots_files
# [NbConvertApp] Making directory ./degradation_plots_files
# [NbConvertApp] Writing 31939 bytes to ./notebook.tex
# [NbConvertApp] Building PDF
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/bin/jupyter-nbconvert", line 8, in <module>
#     sys.exit(main())
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/jupyter_core/application.py", line 270, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/nbconvert/nbconvertapp.py", line 340, in start
#     self.convert_notebooks()
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/nbconvert/nbconvertapp.py", line 510, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/nbconvert/nbconvertapp.py", line 481, in convert_single_notebook
#     output, resources = self.export_single_notebook(notebook_filename, resources, input_buffer=input_buffer)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/nbconvert/nbconvertapp.py", line 410, in export_single_notebook
#     output, resources = self.exporter.from_filename(notebook_filename, resources=resources)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/nbconvert/exporters/exporter.py", line 179, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/nbconvert/exporters/exporter.py", line 197, in from_file
#     return self.from_notebook_node(nbformat.read(file_stream, as_version=4), resources=resources, **kw)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/nbconvert/exporters/pdf.py", line 185, in from_notebook_node
#     self.run_latex(tex_file)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/nbconvert/exporters/pdf.py", line 155, in run_latex
#     return self.run_command(self.latex_command, filename,
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/nbconvert/exporters/pdf.py", line 112, in run_command
#     raise OSError("{formatter} not found on PATH, if you have not installed "
# OSError: xelatex not found on PATH, if you have not installed xelatex you may need to do so. Find further instructions at https://nbconvert.readthedocs.io/en/latest/install.html#installing-tex.

# %%
# !pip install ntbconvert
# Out:
# ERROR: Could not find a version that satisfies the requirement ntbconvert (from versions: none)
# ERROR: No matching distribution found for ntbconvert
# WARNING: You are using pip version 20.0.2; however, version 20.2.2 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.8/bin/python3.8 -m pip install --upgrade pip' command.
