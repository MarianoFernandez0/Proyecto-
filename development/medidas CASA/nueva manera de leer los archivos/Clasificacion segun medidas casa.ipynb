# %%
import numpy as np
import pandas as pd

# %%
param_who = pd.read_csv("param_who.csv")

# %%
# calculo de parametros que se necesitan
param_who[['vap_mean','vap_std','alh_mean','alh_std','bcf_mean','bcf_std']]
# Out:
#     vap_mean     vap_std  alh_mean   alh_std  bcf_mean   bcf_std
# 0   0.000000    0.000000  0.000000  0.000000  0.000000  0.000000
# 1   0.609052   18.825115  0.351013  0.884274  0.478261  0.499527
# 2   2.386835    1.566141  0.573045  0.447951  0.500000  0.500000
# 3   1.537175    7.629832  0.679787  0.980352  0.422414  0.493944
# 4   2.702899    3.758429  1.679126  1.209674  0.666667  0.471405
# 5   2.118679   52.133244  0.642524  1.016534  0.405172  0.490925
# 6   2.177083   26.804983  0.819760  1.286945  0.439655  0.496345
# 7   3.381067   16.893722  1.722347  1.378954  0.431034  0.495221
# 8   2.117441    8.970342  0.807084  1.888860  0.517241  0.499703
# 9   0.908850   34.906891  0.504076  0.762217  0.456897  0.498139
# 10  1.944086    2.384244  0.870593  0.676209  0.525862  0.499331
# 11  1.983178    1.688550  0.883739  0.866434  0.549020  0.497591
# 12  3.383821    5.416529  1.690086  1.201132  0.448276  0.497317
# ...
