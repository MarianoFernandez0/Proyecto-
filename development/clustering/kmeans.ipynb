# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.cluster

# %%
# load df
who_measures = pd.read_csv('input/Archive/measures/dataset_1/dataset_1_30Hz_ennjpdaf_WHO.csv')
who_measures.head()
# Out:
#    track_id       vcl       vsl  vap_mean    vap_std  alh_mean   alh_std  \
# 0         0  0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# 1         1  6.746085  1.669987  4.505772  12.498562  1.899712  1.622582
# 2         2  6.586542  3.207075  3.655710   5.579378  2.206809  3.193406
# 3         3  8.372067  1.144585  4.367589  73.657785  2.710983  2.502473
# 4         4  6.941007  1.247587  4.256971   9.530973  2.517227  1.229993
#
#         lin       wob      stra  bcf_mean   bcf_std       mad
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.247549  0.667909  0.370633  0.738636  0.439378  2.623755
# 2  0.486913  0.555027  0.877278  0.845361  0.361560  1.335038
# 3  0.136715  0.521686  0.262063  0.603774  0.489113  1.764570
# 4  0.179741  0.613307  0.293069  0.782609  0.412471  1.845644

# %%
# remove id col
measures = who_measures.drop('track_id', axis=1)
measures.head()
# Out:
#         vcl       vsl  vap_mean    vap_std  alh_mean   alh_std       lin  \
# 0  0.000000  0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 1  6.746085  1.669987  4.505772  12.498562  1.899712  1.622582  0.247549
# 2  6.586542  3.207075  3.655710   5.579378  2.206809  3.193406  0.486913
# 3  8.372067  1.144585  4.367589  73.657785  2.710983  2.502473  0.136715
# 4  6.941007  1.247587  4.256971   9.530973  2.517227  1.229993  0.179741
#
#         wob      stra  bcf_mean   bcf_std       mad
# 0  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.667909  0.370633  0.738636  0.439378  2.623755
# 2  0.555027  0.877278  0.845361  0.361560  1.335038
# 3  0.521686  0.262063  0.603774  0.489113  1.764570
# 4  0.613307  0.293069  0.782609  0.412471  1.845644

# %%
cluster.KMeans
