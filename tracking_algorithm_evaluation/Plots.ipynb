# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
datasets_dir = 'error_results/urbano'
files = sorted(os.listdir(datasets_dir))
frecuencies = ['7Hz', '15Hz', '30Hz', '40Hz', '50Hz', '60Hz']
algorithms = ['NN', 'GNN', 'PDAF', 'JPDAF', 'ENNJPDAF']

print(files)
print(frecuencies)
print(algorithms)
# Out:
# ['dataset_1_performance_measures.csv', 'dataset_2_performance_measures.csv', 'dataset_3_performance_measures.csv', 'dataset_4_performance_measures.csv', 'dataset_5_performance_measures.csv', 'dataset_6_performance_measures.csv']
# ['7Hz', '15Hz', '30Hz', '40Hz', '50Hz', '60Hz']
# ['NN', 'GNN', 'PDAF', 'JPDAF', 'ENNJPDAF']

# %%
datasets = []
for file in files:
    tracks = pd.read_csv(os.path.join(datasets_dir, file), index_col=0)
    datasets.append(tracks)
    print('Numbe'Passing list-likes to .loc or [] with any missing labels is no longer supportedr of tests', file, tracks.shape[0])
tracks.head(-1)
# Out:
# Number of tests dataset_1_performance_measures.csv 25
# Number of tests dataset_2_performance_measures.csv 30
# Number of tests dataset_3_performance_measures.csv 30
# Number of tests dataset_4_performance_measures.csv 30
# Number of tests dataset_5_performance_measures.csv 25
# Number of tests dataset_6_performance_measures.csv 30
#                   alpha      beta  TP Tracks  FN Tracks  FP Tracks  \
# 50Hz_PDAF      0.354189  0.275147       43.0       14.0       34.0
# 60Hz_PDAF      0.382164  0.318309       41.0       10.0       29.0
# 7Hz_ENNJPDAF   0.722361  0.682441       37.0       11.0        2.0
# 60Hz_JPDAF     0.517192  0.487012       38.0       13.0       11.0
# 40Hz_PDAF      0.391919  0.331606       40.0       12.0       23.0
# 15Hz_PDAF      0.490251  0.395079       41.0       16.0       17.0
# 7Hz_PDAF       0.558989  0.470511       36.0       12.0        8.0
# 40Hz_GNN       0.704451  0.668829       40.0       12.0        8.0
# 30Hz_PDAF      0.473831  0.372182       42.0       11.0       23.0
# 30Hz_GNN       0.737456  0.717679       42.0       11.0        7.0
# 15Hz_JPDAF     0.664502  0.630425       42.0       15.0        7.0
# 60Hz_NN        0.645037  0.569455       42.0        9.0       22.0
# 50Hz_JPDAF     0.486561  0.417341       36.0       21.0       16.0
# 50Hz_ENNJPDAF  0.686911  0.625764       41.0       16.0       14.0
# 50Hz_NN        0.580445  0.493622       44.0       13.0       23.0
# 7Hz_JPDAF      0.659372  0.622186       37.0       11.0        2.0
# 30Hz_NN        0.728769  0.677529       43.0       10.0       10.0
# 7Hz_GNN        0.722769  0.682827       37.0       11.0        2.0
# 15Hz_GNN       0.720454  0.686186       40.0       17.0        8.0
# 60Hz_GNN       0.764576  0.755168       41.0       10.0       10.0
# 30Hz_JPDAF     0.700058  0.657387       41.0       12.0        6.0
# 60Hz_ENNJPDAF  0.764536  0.755128       41.0       10.0       10.0
# 40Hz_JPDAF     0.547424  0.520523       37.0       15.0        7.0
# 30Hz_ENNJPDAF  0.730159  0.710578       42.0       11.0        7.0
# 15Hz_NN        0.739410  0.683954       40.0       17.0        8.0
# 50Hz_GNN       0.662659  0.603195       41.0       16.0       15.0
# 15Hz_ENNJPDAF  0.712988  0.679074       40.0       17.0        8.0
# 40Hz_ENNJPDAF  0.705725  0.670038       40.0       12.0        8.0
# 50Hz_JPDAF           3875.0        1907.0        1844.0       0.508130
# 50Hz_ENNJPDAF        4669.0        1113.0        1145.0       0.674029
# 50Hz_NN              3982.0        1800.0        1653.0       0.535575
# 7Hz_JPDAF             585.0         101.0         107.0       0.737705
# 30Hz_NN              2724.0         542.0         553.0       0.713276
# 7Hz_GNN               618.0         100.0         114.0       0.742788
# 15Hz_GNN             1434.0         268.0         270.0       0.727181
# 60Hz_GNN             5588.0         673.0         631.0       0.810795
# 30Hz_JPDAF           2844.0         422.0         464.0       0.762466
# 60Hz_ENNJPDAF        5585.0         676.0         633.0       0.810125
# 40Hz_JPDAF           3185.0        1246.0         764.0       0.613090
# 30Hz_ENNJPDAF        2796.0         470.0         499.0       0.742629
# 15Hz_NN              1454.0         248.0         260.0       0.741081
# 50Hz_GNN             4537.0        1245.0        1220.0       0.647958
# 15Hz_ENNJPDAF        1437.0         265.0         265.0       0.730554
# 40Hz_ENNJPDAF        3507.0         924.0         676.0       0.686705
# 40Hz_NN              3315.0        1116.0         968.0       0.614003
#
#                       OSPA
# 50Hz_PDAF      2668.488150
# 60Hz_PDAF      3406.147970
# 7Hz_ENNJPDAF    110.204215
# 60Hz_JPDAF     2287.502453
# 40Hz_PDAF      2050.158190
# 15Hz_PDAF       640.891821
# 7Hz_PDAF        198.236562
# 40Hz_GNN        948.862692
# 30Hz_PDAF      1341.383322
# 30Hz_GNN        535.405379
# 15Hz_JPDAF      407.025269
# 60Hz_NN        1760.810972
# 50Hz_JPDAF     1963.737946
# 50Hz_ENNJPDAF  1153.879654
# 50Hz_NN        1701.871003
# 7Hz_JPDAF       141.440443
# 30Hz_NN         629.724731
# 7Hz_GNN         111.637908
# 15Hz_GNN        309.654171
# 60Hz_GNN       1015.280486
# 30Hz_JPDAF      700.818035
# 60Hz_ENNJPDAF  1017.459597
# 40Hz_JPDAF     1624.831626
# 30Hz_ENNJPDAF   535.189706
# 15Hz_NN         293.528665
# 50Hz_GNN       1260.403747
# 15Hz_ENNJPDAF   317.578133
# 40Hz_ENNJPDAF   944.362069
# 40Hz_NN        1077.801177

# %% [markdown]
# Dataset 1:

# %%
results = datasets[0]
results_att_sort = []
for att in algorithms: 
    idxs = [idx for idx in results.index if att == idx.split(sep='_')[1]]
    results_att = results.loc[idxs, :]
    results_att_sort.append(results_att)
results_att.head(-1)
# Out:
#                   alpha      beta  TP Tracks  FN Tracks  FP Tracks  \
# 60Hz_ENNJPDAF  0.749403  0.731800       48.0        6.0       21.0
# 40Hz_ENNJPDAF  0.809057  0.798248       47.0        3.0        6.0
# 15Hz_ENNJPDAF  0.622059  0.589859       34.0       13.0        9.0
# 7Hz_ENNJPDAF   0.755641  0.734706       37.0        6.0        5.0
#
#                JSC Tracks         RMSE        Min          Max           SD  \
# 60Hz_ENNJPDAF    0.640000  1866.369789  63.137723  6692.480422  1465.104342
# 40Hz_ENNJPDAF    0.839286  1089.375473  43.702084  4709.312943   899.422588
# 15Hz_ENNJPDAF    0.607143   641.994254  43.468761  1715.328468   468.915705
# 7Hz_ENNJPDAF     0.770833   248.688892  41.108798   760.237814   172.059357
#
#                TP Positions  FN Positions  FP Positions  JSC Positions  \
# 60Hz_ENNJPDAF        5530.0        1080.0         884.0       0.737924
# 40Hz_ENNJPDAF        3979.0         515.0         379.0       0.816540
# 15Hz_ENNJPDAF         968.0         296.0         326.0       0.608805
# 7Hz_ENNJPDAF          647.0          90.0         111.0       0.762972
#
#                       OSPA
# 60Hz_ENNJPDAF  1228.201934
# 40Hz_ENNJPDAF   638.633476
# 15Hz_ENNJPDAF   430.004879
# 7Hz_ENNJPDAF    100.241798

# %%
for i, results_att in enumerate(results_att_sort):
    for idx in results_att.index:
        frec = idx.split(sep='_')[0]
        frec = frec[:-2]
        results_att.loc[idx, 'Frecuency'] = int(frec) 
    
results_att.head()
# Out:
#                   alpha      beta  TP Tracks  FN Tracks  FP Tracks  \
# 60Hz_ENNJPDAF  0.749403  0.731800       48.0        6.0       21.0
# 40Hz_ENNJPDAF  0.809057  0.798248       47.0        3.0        6.0
# 15Hz_ENNJPDAF  0.622059  0.589859       34.0       13.0        9.0
# 7Hz_ENNJPDAF   0.755641  0.734706       37.0        6.0        5.0
# 30Hz_ENNJPDAF  0.737353  0.708360       39.0        8.0        4.0
#
#                JSC Tracks         RMSE        Min          Max           SD  \
# 60Hz_ENNJPDAF    0.640000  1866.369789  63.137723  6692.480422  1465.104342
# 40Hz_ENNJPDAF    0.839286  1089.375473  43.702084  4709.312943   899.422588
# 15Hz_ENNJPDAF    0.607143   641.994254  43.468761  1715.328468   468.915705
# 7Hz_ENNJPDAF     0.770833   248.688892  41.108798   760.237814   172.059357
# 30Hz_ENNJPDAF    0.764706   964.889329  52.539541  3224.846217   753.098313
#
#                TP Positions  FN Positions  FP Positions  JSC Positions  \
# 60Hz_ENNJPDAF        5530.0        1080.0         884.0       0.737924
# 40Hz_ENNJPDAF        3979.0         515.0         379.0       0.816540
# 15Hz_ENNJPDAF         968.0         296.0         326.0       0.608805
# 7Hz_ENNJPDAF          647.0          90.0         111.0       0.762972
# 30Hz_ENNJPDAF        2519.0         464.0         536.0       0.715828
#
#                       OSPA  Frecuency
# 60Hz_ENNJPDAF  1228.201934       60.0
# 40Hz_ENNJPDAF   638.633476       40.0
# 15Hz_ENNJPDAF   430.004879       15.0
# 7Hz_ENNJPDAF    100.241798        7.0
# 30Hz_ENNJPDAF   626.972814       30.0

# %% [markdown]
# OSPA:

# %%
plt.figure(figsize=(20, 10))
for i, results_att in enumerate(results_att_sort):
    results_att = results_att.sort_values(by=['Frecuency'])
    plt.plot(results_att['Frecuency'], results_att['OSPA'], marker='o', markersize=5,
             label=results_att.index[0].split(sep='_')[1])
plt.legend()
plt.grid()
plt.title('OSPA - Frecuency:')
plt.show()
# results_att.plot(y='OSPA', x='Frecuency', subplots=True,figsize=(20,5),
# use_index=True, legend=True, rot=0, grid=True, title=('OSPA - Frecuency:'))

# %% [markdown]
# Jaccard Tracks:

# %%
plt.figure(figsize=(20, 10))
for i, results_att in enumerate(results_att_sort):
    results_att = results_att.sort_values(by=['Frecuency'])
    plt.plot(results_att['Frecuency'], results_att['JSC Tracks'], marker='o', markersize=5,
             label=results_att.index[0].split(sep='_')[1])
plt.legend()
plt.grid()
plt.title('JSC Tracks - Frecuency:')
plt.show()

# %% [markdown]
# Jaccard Positions:

# %%
plt.figure(figsize=(20, 10))
for i, results_att in enumerate(results_att_sort):
    results_att = results_att.sort_values(by=['Frecuency'])
    plt.plot(results_att['Frecuency'], results_att['JSC Positions'], marker='o', markersize=5,
             label=results_att.index[0].split(sep='_')[1])
plt.legend()
plt.grid()
plt.title('JSC Positions - Frecuency:')
plt.show()

# %%
for _, results in enumerate(datasets):
    print(files[i])
    results_att_sort = []
    for att in algorithms: 
        idxs = [idx for idx in results.index if att == idx.split(sep='_')[1]]
        results_att = results.loc[idxs, :]
        results_att_sort.append(results_att)

    for i, results_att in enumerate(results_att_sort):
        for idx in results_att.index:
            frec = idx.split(sep='_')[0]
            frec = frec[:-2]
            results_att.loc[idx, 'Frecuency'] = int(frec) 

    plt.figure(figsize=(20, 10))
    for i, results_att in enumerate(results_att_sort):
        results_att = results_att.sort_values(by=['Frecuency'])
        plt.plot(results_att['Frecuency'], results_att['OSPA'], marker='o', markersize=5,
                 label=results_att.index[0].split(sep='_')[1])
    plt.legend()
    plt.grid()
    plt.title('OSPA - Frecuency:')
    plt.show()

    plt.figure(figsize=(20, 10))
    for i, results_att in enumerate(results_att_sort):
        results_att = results_att.sort_values(by=['Frecuency'])
        plt.plot(results_att['Frecuency'], results_att['JSC Tracks'], marker='o', markersize=5,
                 label=results_att.index[0].split(sep='_')[1])
    plt.legend()
    plt.grid()
    plt.title('JSC Tracks - Frecuency:')
    plt.show()

    plt.figure(figsize=(20, 10))
    for i, results_att in enumerate(results_att_sort):
        results_att = results_att.sort_values(by=['Frecuency'])
        plt.plot(results_att['Frecuency'], results_att['JSC Positions'], marker='o', markersize=5,
                 label=results_att.index[0].split(sep='_')[1])
    plt.legend()
    plt.grid()
    plt.title('JSC Positions - Frecuency:')
    plt.show()
# Out:
# dataset_1_performance_measures.csv
# dataset_5_performance_measures.csv
# dataset_5_performance_measures.csv
# dataset_5_performance_measures.csv
# dataset_5_performance_measures.csv
# dataset_5_performance_measures.csv

# %%
results = datasets[0]
results_frec_sort = []
for frec in frecuencies: 
    if frec == '50Hz':
        continue
    idxs = [idx for idx in tracks.index if str(frec) in idx]
    results_frec = results.loc[idxs, :]
    results_frec_sort.append(results_frec)

# %%
for i, results_frec in enumerate(results_frec_sort):
    tracks_frec.plot.bar(y=['JSC Tracks', 'JSC Positions'], subplots=False,figsize=(20,5),
                         use_index=True, legend=True, rot=0, grid=True, title=('Frecuency: ' + frecuencies[i]))
    tracks_frec.plot.bar(y=['OSPA'], subplots=False,figsize=(20,5),
                         use_index=True, legend=True, rot=0, grid=True, title=('Frecuency: ' + frecuencies[i]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-88302e93f6e3> in <module>
#       1 for i, results_frec in enumerate(results_frec_sort):
# ----> 2     tracks_frec.plot.bar(y=['JSC Tracks', 'JSC Positions'], subplots=False,figsize=(20,5),
#       3                          use_index=True, legend=True, rot=0, grid=True, title=('Frecuency: ' + frecuencies[i]))
#       4     tracks_frec.plot.bar(y=['OSPA'], subplots=False,figsize=(20,5),
#       5                          use_index=True, legend=True, rot=0, grid=True, title=('Frecuency: ' + frecuencies[i]))
#
# NameError: name 'tracks_frec' is not defined
