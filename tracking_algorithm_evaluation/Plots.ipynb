# %%
import pandas as pd
import numpy as np

# %%
tracks_octave = pd.read_csv('performance_measures_octave.csv', index_col=0)
tracks_trackmate = pd.read_csv('performance_measures_trackmate.csv', index_col=0)
tracks_c = pd.read_csv('performance_measures_c++.csv', index_col=0)
tracks = pd.concat((tracks_octave, tracks_trackmate, tracks_c))
tracks.head(10)
# Out:
#                                       alpha      beta  TP Tracks  FN Tracks  \
# dataset_1_30Hz_tracking_jpdaf      0.586826  0.560503       35.0       20.0
# dataset_1_30Hz_tracking_pdaf       0.469497  0.389713       38.0       17.0
# dataset_1_30Hz_tracking_NN         0.644783  0.591550       37.0       18.0
# dataset_1_30Hz_tracking_enn_jpdaf  0.715394  0.705475       37.0       18.0
# dataset_1_30Hz_tracking_GNN        0.722632  0.712612       37.0       18.0
# dataset_2_30Hz_tracking_jpdaf      0.465827  0.443489       49.0       38.0
# dataset_2_30Hz_tracking_pdaf       0.376905  0.311625       52.0       35.0
# dataset_2_30Hz_tracking_NN         0.587543  0.513518       59.0       28.0
# dataset_2_30Hz_tracking_enn_jpdaf  0.550130  0.520720       52.0       35.0
# dataset_2_30Hz_tracking_GNN        0.523999  0.491087       52.0       35.0
#
#                                    FP Tracks  JSC Tracks         RMSE  \
# ...

# %%
dataset = 'dataset_1_10Hz'
bool_idx = []
for idx in tracks.index:
    bool_idx.append(dataset in idx)
tracks_dataset_1_10Hz = tracks.loc[bool_idx, :]
tracks_dataset_1_10Hz.head()
# Out:
#                                       alpha      beta  TP Tracks  FN Tracks  \
# dataset_1_10Hz_tracking_jpdaf      0.511292  0.470443       33.0       18.0
# dataset_1_10Hz_tracking_pdaf       0.478934  0.386094       33.0       18.0
# dataset_1_10Hz_tracking_NN         0.617878  0.536484       36.0       15.0
# dataset_1_10Hz_tracking_enn_jpdaf  0.575131  0.530112       35.0       16.0
# dataset_1_10Hz_tracking_GNN        0.575974  0.531356       35.0       16.0
#
#                                    FP Tracks  JSC Tracks        RMSE  \
# dataset_1_10Hz_tracking_jpdaf            8.0    0.559322  537.915624
# dataset_1_10Hz_tracking_pdaf            13.0    0.515625  605.999630
# dataset_1_10Hz_tracking_NN              13.0    0.562500  436.947546
# dataset_1_10Hz_tracking_enn_jpdaf        9.0    0.583333  467.182823
# dataset_1_10Hz_tracking_GNN              9.0    0.583333  479.192424
#
#                                          Min          Max          SD  \
# ...

# %%
# tracks_dataset_1_10Hz.plot.bar(y='JSC Tracks', subplots=True,figsize=(20,5),
#                                use_index=True, legend = False, rot=0)
# tracks_dataset_1_10Hz.plot.bar(y='JSC Positions', subplots=True,figsize=(20,5),
#                                use_index=True, legend = False, rot=0)
# tracks_dataset_1_10Hz.plot.bar(y='RMSE', subplots=True,figsize=(20,5),
#                                use_index=True, legend = False, rot=0)

# %%
tracks_dataset_1_10Hz.plot.bar(y=['JSC Tracks', 'JSC Positions'], subplots=False,figsize=(20,5),
                               use_index=True, legend=True, rot=0, grid=True)
tracks_dataset_1_10Hz.plot.bar(y=['OSPA'], subplots=False,figsize=(20,5),
                               use_index=True, legend=True, rot=0, grid=True)

# %%
dataset = 'dataset_1_20Hz'
bool_idx = []
for idx in tracks.index:
    bool_idx.append(dataset in idx)
tracks_dataset_1_20Hz = tracks.loc[bool_idx, :]
tracks_dataset_1_20Hz.head()
# Out:
#                                       alpha      beta  TP Tracks  FN Tracks  \
# dataset_1_20Hz_tracking_jpdaf      0.512791  0.475094       30.0       24.0
# dataset_1_20Hz_tracking_pdaf       0.431688  0.386900       30.0       24.0
# dataset_1_20Hz_tracking_NN         0.521452  0.480403       32.0       21.0
# dataset_1_20Hz_tracking_enn_jpdaf  0.548431  0.507578       30.0       23.0
# dataset_1_20Hz_tracking_GNN        0.568180  0.530730       31.0       22.0
#
#                                    FP Tracks  JSC Tracks         RMSE  \
# dataset_1_20Hz_tracking_jpdaf           17.0    0.422535   781.471581
# dataset_1_20Hz_tracking_pdaf            21.0    0.400000  1111.563633
# dataset_1_20Hz_tracking_NN              17.0    0.457143   901.830058
# dataset_1_20Hz_tracking_enn_jpdaf       17.0    0.428571   701.513633
# dataset_1_20Hz_tracking_GNN             16.0    0.449275   624.568325
#
#                                          Min          Max          SD  \
# ...

# %%
tracks_dataset_1_20Hz.plot.bar(y=['JSC Tracks', 'JSC Positions'], subplots=False,figsize=(20,5),
                               use_index=True, legend=True, rot=0, grid=True)
tracks_dataset_1_20Hz.plot.bar(y=['OSPA'], subplots=False,figsize=(20,5),
                               use_index=True, legend=True, rot=0, grid=True)

# %%
dataset = 'dataset_1_30Hz'
bool_idx = []
for idx in tracks.index:
    bool_idx.append(dataset in idx)
tracks_dataset_1_30Hz = tracks.loc[bool_idx, :]
tracks_dataset_1_30Hz.head()
# Out:
#                                       alpha      beta  TP Tracks  FN Tracks  \
# dataset_1_30Hz_tracking_jpdaf      0.586826  0.560503       35.0       20.0
# dataset_1_30Hz_tracking_pdaf       0.469497  0.389713       38.0       17.0
# dataset_1_30Hz_tracking_NN         0.644783  0.591550       37.0       18.0
# dataset_1_30Hz_tracking_enn_jpdaf  0.715394  0.705475       37.0       18.0
# dataset_1_30Hz_tracking_GNN        0.722632  0.712612       37.0       18.0
#
#                                    FP Tracks  JSC Tracks         RMSE  \
# dataset_1_30Hz_tracking_jpdaf           10.0    0.538462  1045.261377
# dataset_1_30Hz_tracking_pdaf            23.0    0.487179  2034.258453
# dataset_1_30Hz_tracking_NN              15.0    0.528571  1112.139261
# dataset_1_30Hz_tracking_enn_jpdaf        9.0    0.578125   662.097970
# dataset_1_30Hz_tracking_GNN              9.0    0.578125   634.172215
#
#                                          Min          Max           SD  \
# ...

# %%
tracks_dataset_1_30Hz.plot.bar(y=['JSC Tracks', 'JSC Positions'], subplots=False,figsize=(20,5),
                               use_index=True, legend=True, rot=0, grid=True)
tracks_dataset_1_30Hz.plot.bar(y=['OSPA'], subplots=False,figsize=(20,5),
                               use_index=True, legend=True, rot=0, grid=True)

# %%
dataset = 'dataset_1_40Hz'
bool_idx = []
for idx in tracks.index:
    bool_idx.append(dataset in idx)
tracks_dataset_1_40Hz = tracks.loc[bool_idx, :]
tracks_dataset_1_40Hz.head()
# Out:
#                              alpha      beta  TP Tracks  FN Tracks  FP Tracks  \
# dataset_1_40Hz_jpdaf      0.531619  0.489280       48.0       15.0       17.0
# dataset_1_40Hz_pdaf       0.445198  0.342396       48.0       15.0       41.0
# dataset_1_40Hz_NN         0.554139  0.480247       50.0       13.0       29.0
# dataset_1_40Hz_enn_jpdaf  0.677143  0.645433       49.0       14.0       15.0
# dataset_1_40Hz_GNN        0.678023  0.647394       50.0       13.0       14.0
#
#                           JSC Tracks         RMSE        Min          Max  \
# dataset_1_40Hz_jpdaf        0.600000  2287.575630  65.464168  5886.555688
# dataset_1_40Hz_pdaf         0.461538  2630.903847  94.173696  5839.731416
# dataset_1_40Hz_NN           0.543478  2279.145141  52.825023  5730.850000
# dataset_1_40Hz_enn_jpdaf    0.628205  1617.530757  47.406698  5459.164856
# dataset_1_40Hz_GNN          0.649351  1795.553813  52.825023  5777.530707
#
# ...

# %%
tracks_dataset_1_40Hz.plot.bar(y=['JSC Tracks', 'JSC Positions'], subplots=False,figsize=(20,5),
                               use_index=True, legend=True, rot=0, grid=True)

# %%
dataset = 'dataset_2_10Hz'
bool_idx = []
for idx in tracks.index:
    bool_idx.append(dataset in idx)
tracks_dataset_2_10Hz = tracks.loc[bool_idx, :]
tracks_dataset_2_10Hz.head()
# Out:
#                              alpha      beta  TP Tracks  FN Tracks  FP Tracks  \
# dataset_2_10Hz_jpdaf      0.541694  0.493196       50.0       26.0       14.0
# dataset_2_10Hz_pdaf       0.486697  0.389617       49.0       27.0       19.0
# dataset_2_10Hz_NN         0.598989  0.515259       51.0       25.0       15.0
# dataset_2_10Hz_enn_jpdaf  0.604330  0.544851       51.0       25.0       14.0
# dataset_2_10Hz_GNN        0.516652  0.471111       51.0       25.0       14.0
#
#                           JSC Tracks        RMSE         Min          Max  \
# dataset_2_10Hz_jpdaf        0.555556  388.512231   81.444214   955.752378
# dataset_2_10Hz_pdaf         0.515789  443.559968  123.670749  1001.956033
# dataset_2_10Hz_NN           0.560440  352.205229   49.087738   945.931758
# dataset_2_10Hz_enn_jpdaf    0.566667  336.125184   49.087738   839.039021
# dataset_2_10Hz_GNN          0.566667  428.285088   55.530653  1204.382063
#
# ...

# %%
tracks_dataset_2_10Hz.plot.bar(y=['JSC Tracks', 'JSC Positions'], subplots=False,figsize=(20,5),
                               use_index=True, legend=True, rot=0, grid=True)

# %%
dataset = 'dataset_2_20Hz'
bool_idx = []
for idx in tracks.index:
    bool_idx.append(dataset in idx)
tracks_dataset_2_20Hz = tracks.loc[bool_idx, :]
tracks_dataset_2_20Hz.head()
# Out:
#                              alpha      beta  TP Tracks  FN Tracks  FP Tracks  \
# dataset_2_20Hz_jpdaf      0.519407  0.507645       61.0       22.0        5.0
# dataset_2_20Hz_pdaf       0.406567  0.330085       61.0       22.0       31.0
# dataset_2_20Hz_NN         0.575793  0.493114       66.0       16.0       22.0
# dataset_2_20Hz_enn_jpdaf  0.507774  0.476038       60.0       22.0        9.0
# dataset_2_20Hz_GNN        0.494914  0.446726       58.0       24.0       10.0
#
#                           JSC Tracks         RMSE        Min          Max  \
# dataset_2_20Hz_jpdaf        0.693182   973.101267  44.088263  2686.039126
# dataset_2_20Hz_pdaf         0.535088  1303.492838  44.088263  2679.578788
# dataset_2_20Hz_NN           0.634615  1023.002074  43.926717  2651.346864
# dataset_2_20Hz_enn_jpdaf    0.659341   991.427613  43.926717  2681.100723
# dataset_2_20Hz_GNN          0.630435   994.243851  43.926717  2395.745472
#
# ...

# %%
tracks_dataset_2_20Hz.plot.bar(y=['JSC Tracks', 'JSC Positions'], subplots=False,figsize=(20,5),
                               use_index=True, legend=True, rot=0, grid=True)

# %%
dataset = 'dataset_2_30Hz'
bool_idx = []
for idx in tracks.index:
    bool_idx.append(dataset in idx)
tracks_dataset_2_30Hz = tracks.loc[bool_idx, :]
tracks_dataset_2_30Hz.head()
# Out:
#                              alpha      beta  TP Tracks  FN Tracks  FP Tracks  \
# dataset_2_30Hz_jpdaf      0.465827  0.443489       49.0       38.0        9.0
# dataset_2_30Hz_pdaf       0.376905  0.311625       52.0       35.0       20.0
# dataset_2_30Hz_NN         0.587543  0.513518       59.0       28.0       17.0
# dataset_2_30Hz_enn_jpdaf  0.550130  0.520720       52.0       35.0        8.0
# dataset_2_30Hz_GNN        0.523999  0.491087       52.0       35.0        9.0
#
#                           JSC Tracks         RMSE         Min          Max  \
# dataset_2_30Hz_jpdaf        0.510417  1528.150935   83.408342  3866.876279
# dataset_2_30Hz_pdaf         0.485981  1826.848061  153.516394  4327.919473
# dataset_2_30Hz_NN           0.567308  1310.736896   56.664643  4391.298747
# dataset_2_30Hz_enn_jpdaf    0.547368  1192.616832   56.664643  3773.696461
# dataset_2_30Hz_GNN          0.541667  1301.118832   56.664643  3773.696461
#
# ...

# %%
tracks_dataset_2_30Hz.plot.bar(y=['JSC Tracks', 'JSC Positions'], subplots=False,figsize=(20,5),
                               use_index=True, legend=True, rot=0, grid=True)

# %%
dataset = 'dataset_2_40Hz'
bool_idx = []
for idx in tracks.index:
    bool_idx.append(dataset in idx)
tracks_dataset_2_40Hz = tracks.loc[bool_idx, :]
tracks_dataset_2_40Hz.head()
# Out:
#                              alpha      beta  TP Tracks  FN Tracks  FP Tracks  \
# dataset_2_40Hz_jpdaf      0.523459  0.480723       64.0       22.0       13.0
# dataset_2_40Hz_pdaf       0.363282  0.269954       69.0       17.0       56.0
# dataset_2_40Hz_NN         0.581912  0.474868       69.0       17.0       36.0
# dataset_2_40Hz_enn_jpdaf  0.638459  0.610900       69.0       17.0       10.0
# dataset_2_40Hz_GNN        0.625984  0.599979       70.0       16.0       10.0
#
#                           JSC Tracks         RMSE         Min          Max  \
# dataset_2_40Hz_jpdaf        0.646465  2013.093263  130.635222  5180.853610
# dataset_2_40Hz_pdaf         0.485915  2668.298902  187.203896  5338.721384
# dataset_2_40Hz_NN           0.565574  1853.147676   78.031276  4647.464101
# dataset_2_40Hz_enn_jpdaf    0.718750  1594.527815   97.904354  4738.906198
# dataset_2_40Hz_GNN          0.729167  1670.846352   59.986393  4738.924509
#
# ...

# %%
tracks_dataset_2_40Hz.plot.bar(y=['JSC Tracks', 'JSC Positions'], subplots=False,figsize=(20,5),
                               use_index=True, legend=True, rot=0, grid=True)
